# %% [markdown]
# # Pre-requisite
# - We need to create a data lake account and also upload the input file to it
# - Also need to create Service Principal and then allow access to SP on the Data Lake container which contains input files

# %% [markdown]
# ## Mount Data from Data Lake

# %%
# Specify the Data Lake account details
adlsAccountName = "adlsjune22"
adlsContainerName = "inputdata"
adlsFolderName = "data"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Specify details of SP which will be used in this notebook to connect to the Data Lake account
applicationId = "cd73353b-8835-40f0-9ff6-94456cd05e26"
authenticationKey = "PW58Q~2UH2nCuTmIgrhPH.iV_rOU4k81vxUnJdsp"
tenandId = "6bb2f9af-a0af-4c32-a5ec-5f7011d37551"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
endpoint = "https://login.microsoftonline.com/" + tenandId + "/oauth2/token"
source = "abfss://" + adlsContainerName + "@" + adlsAccountName + ".dfs.core.windows.net/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": applicationId,
           "fs.azure.account.oauth2.client.secret": authenticationKey,
           "fs.azure.account.oauth2.client.endpoint": endpoint}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.unmount("/mnt/data")
print("Source: ", source)
print("configs: ", configs)
print("endpoint: ", endpoint)

print("applicationId: ", applicationId)
print("authenticationKey: ", authenticationKey)
print("tenandId: ", tenandId)

print("adlsAccountName: ", adlsAccountName)
print("adlsContainerName: ", adlsContainerName)

print("adlsFolderName: ", adlsFolderName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Source:  abfss://inputdata@adlsjune22.dfs.core.windows.net/
# configs:  {&#39;fs.azure.account.auth.type&#39;: &#39;OAuth&#39;, &#39;fs.azure.account.oauth.provider.type&#39;: &#39;org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider&#39;, &#39;fs.azure.account.oauth2.client.id&#39;: &#39;cd73353b-8835-40f0-9ff6-94456cd05e26&#39;, &#39;fs.azure.account.oauth2.client.secret&#39;: &#39;PW58Q~2UH2nCuTmIgrhPH.iV_rOU4k81vxUnJdsp&#39;, &#39;fs.azure.account.oauth2.client.endpoint&#39;: &#39;https://login.microsoftonline.com/6bb2f9af-a0af-4c32-a5ec-5f7011d37551/oauth2/token&#39;}
# ...

# %%
try:
  dbutils.fs.mount(source = source,mount_point = "/mnt/data",extra_configs = configs)
except Exception as e:
  print(e)
  #pass
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">An error occurred while calling o458.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/data; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/data
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.createOrUpdateMount(DBUtilsCore.scala:756)
# ...

# %%
# %fs ls /mnt/data/data/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/data/Customer/</td><td>Customer/</td><td>0</td><td>1654826580000</td></tr><tr><td>dbfs:/mnt/data/data/Orders/</td><td>Orders/</td><td>0</td><td>1654827283000</td></tr></tbody></table></div>

# %%
# %sh
cat /dbfs/mnt/data/data/Orders/csvFiles/part-00000-tid-7102115315925714332-44153d85-ae09-48d7-be48-c00105b3f2cf-126-1-c000.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">O_ORDERKEY,O_CUSTKEY,O_ORDERSTATUS,O_TOTALPRICE,O_ORDERDATE,O_ORDERPRIORITY,O_CLERK,O_SHIPPRIORITY,O_COMMENT
# 22470,54586,F,98905.99,1993-07-22,1-URGENT,Clerk#000000789,0,furiously special f
# 694624,41744,F,241577.66,1994-03-28,3-MEDIUM,Clerk#000000091,0,furiously special f
# 102275,114550,F,97564.48,1993-09-28,4-NOT SPECIFIED,Clerk#000000732,0,furiously special f
# 267266,13177,O,27764.81,1997-12-04,1-URGENT,Clerk#000000929,0,furiously special f
# 286720,33893,O,84110.26,1997-03-22,5-LOW,Clerk#000000662,0,furiously special f
# 722660,940,O,189982.11,1998-02-15,5-LOW,Clerk#000000916,0,furiously special f
# ...
